# %% [markdown]
# # YOUR FIRST LAB
# ### Please read this section. This is valuable to get you prepared, even if it's a long read -- it's important stuff.
#
# ## Your first Frontier LLM Project
#
# Let's build a useful LLM solution - in a matter of minutes.
#
# By the end of this course, you will have built an autonomous Agentic AI solution with 7 agents that collaborate to solve a business problem. All in good time! We will start with something smaller...
#
# Our goal is to code a new kind of Web Browser. Give it a URL, and it will respond with a summary. The Reader's Digest of the internet!!
#
# Before starting, you should have completed the setup for [PC](../SETUP-PC.md) or [Mac](../SETUP-mac.md) and you hopefully launched this jupyter lab from within the project root directory, with your environment activated.
#
# ## If you're new to Jupyter Lab
#
# Welcome to the wonderful world of Data Science experimentation! Once you've used Jupyter Lab, you'll wonder how you ever lived without it. Simply click in each "cell" with code in it, such as the cell immediately below this text, and hit Shift+Return to execute that cell. As you wish, you can add a cell with the + button in the toolbar, and print values of variables, or try out variations.
#
# I've written a notebook called [Guide to Jupyter](Guide%20to%20Jupyter.ipynb) to help you get more familiar with Jupyter Labs, including adding Markdown comments, using `!` to run shell commands, and `tqdm` to show progress.
#
# ## If you're new to the Command Line
#
# Please see these excellent guides: [Command line on PC](https://chatgpt.com/share/67b0acea-ba38-8012-9c34-7a2541052665) and [Command line on Mac](https://chatgpt.com/canvas/shared/67b0b10c93a081918210723867525d2b).
#
# ## If you'd prefer to work in IDEs
#
# If you're more comfortable in IDEs like VSCode, Cursor or PyCharm, they both work great with these lab notebooks too.
# If you'd prefer to work in VSCode, [here](https://chatgpt.com/share/676f2e19-c228-8012-9911-6ca42f8ed766) are instructions from an AI friend on how to configure it for the course.
#
# ## If you'd like to brush up your Python
#
# I've added a notebook called [Intermediate Python](Intermediate%20Python.ipynb) to get you up to speed. But you should give it a miss if you already have a good idea what this code does:
# `yield from {book.get("author") for book in books if book.get("author")}`
#
# ## I am here to help
#
# If you have any problems at all, please do reach out.
# I'm available through the platform, or at ed@edwarddonner.com, or at https://www.linkedin.com/in/eddonner/ if you'd like to connect (and I love connecting!)
# And this is new to me, but I'm also trying out X/Twitter at [@edwarddonner](https://x.com/edwarddonner) - if you're on X, please show me how it's done 😂
#
# ## More troubleshooting
#
# Please see the [troubleshooting](troubleshooting.ipynb) notebook in this folder to diagnose and fix common problems. At the very end of it is a diagnostics script with some useful debug info.
#
# ## For foundational technical knowledge (eg Git, APIs, debugging)
#
# If you're relatively new to programming -- I've got your back! While it's ideal to have some programming experience for this course, there's only one mandatory prerequisite: plenty of patience. 😁 I've put together a set of self-study guides that cover Git and GitHub, APIs and endpoints, beginner python and more.
#
# This covers Git and GitHub; what they are, the difference, and how to use them:
# https://github.com/ed-donner/agents/blob/main/guides/03_git_and_github.ipynb
#
# This covers technical foundations:
# ChatGPT vs API; taking screenshots; Environment Variables; Networking basics; APIs and endpoints:
# https://github.com/ed-donner/agents/blob/main/guides/04_technical_foundations.ipynb
#
# This covers Python for beginners, and making sure that a `NameError` never trips you up:
# https://github.com/ed-donner/agents/blob/main/guides/06_python_foundations.ipynb
#
# This covers the essential techniques for figuring out errors:
# https://github.com/ed-donner/agents/blob/main/guides/08_debugging.ipynb
#
# And you'll find other useful guides in the same folder in GitHub. Some information applies to my other Udemy course (eg Async Python) but most of it is very relevant for LLM engineering.
#
# ## If this is old hat!
#
# If you're already comfortable with today's material, please hang in there; you can move swiftly through the first few labs - we will get much more in depth as the weeks progress. Ultimately we will fine-tune our own LLM to compete with OpenAI!
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Please read - important note</h2>
#             <span style="color:#900;">The way I collaborate with you may be different to other courses you've taken. I prefer not to type code while you watch. Rather, I execute Jupyter Labs, like this, and give you an intuition for what's going on. My suggestion is that you carefully execute this yourself, <b>after</b> watching the lecture. Add print statements to understand what's going on, and then come up with your own variations. If you have a Github account, use this to showcase your variations. Not only is this essential practice, but it demonstrates your skills to others, including perhaps future clients or employers...</span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">This code is a live resource - keep an eye out for my emails</h2>
#             <span style="color:#f71;">I push updates to the code regularly. As people ask questions, I add more examples or improved commentary. As a result, you'll notice that the code below isn't identical to the videos. Everything from the videos is here; but I've also added better explanations and new models like DeepSeek. Consider this like an interactive book.<br/><br/>
#                 I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business value of these exercises</h2>
#             <span style="color:#181;">A final thought. While I've designed these notebooks to be educational, I've also tried to make them enjoyable. We'll do fun things like have LLMs tell jokes and argue with each other. But fundamentally, my goal is to teach skills you can apply in business. I'll explain business implications as we go, and it's worth keeping this in mind: as you build experience with models and techniques, think of ways you could put this into action at work today. Please do contact me if you'd like to discuss more or if you have ideas to bounce off me.</span>
#         </td>
#     </tr>
# </table>

# %%
# imports

import os
import requests
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display
from openai import OpenAI

# If you get an error running this cell, then please head over to the troubleshooting notebook!

# %% [markdown]
# # Connecting to OpenAI (or Ollama)
#
# The next cell is where we load in the environment variables in your `.env` file and connect to OpenAI.
#
# If you'd like to use free Ollama instead, please see the README section "Free Alternative to Paid APIs", and if you're not sure how to do this, there's a full solution in the solutions folder (day1_with_ollama.ipynb).
#
# ## Troubleshooting if you have problems:
#
# Head over to the [troubleshooting](troubleshooting.ipynb) notebook in this folder for step by step code to identify the root cause and fix it!
#
# If you make a change, try restarting the "Kernel" (the python process sitting behind this notebook) by Kernel menu >> Restart Kernel and Clear Outputs of All Cells. Then try this notebook again, starting at the top.
#
# Or, contact me! Message me or email ed@edwarddonner.com and we will get this to work.
#
# Any concerns about API costs? See my notes in the README - costs should be minimal, and you can control it at every point. You can also use Ollama as a free alternative, which we discuss during Day 2.

# %%
# Load environment variables in a file called .env

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

# Check the key

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
elif api_key.strip() != api_key:
    print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")
# Out:
# API key found and looks good so far!

# %%
openai = OpenAI()

# If this doesn't work, try Kernel menu >> Restart Kernel and Clear Outputs Of All Cells, then run the cells from the top of this notebook down.
# If it STILL doesn't work (horrors!) then please see the Troubleshooting notebook in this folder for full instructions

# %% [markdown]
# # Let's make a quick call to a Frontier model to get started, as a preview!

# %%
# To give you a preview -- calling OpenAI with these messages is this easy. Any problems, head over to the Troubleshooting notebook.

message = "Hello, GPT! This is my first ever message to you! Hi!"
response = openai.chat.completions.create(model="gpt-4o-mini", messages=[{"role":"user", "content":message}])
print(response.choices[0].message.content)
# Out:
# Hello! Welcome! I'm glad you're here. How can I assist you today?

# %% [markdown]
# ## OK onwards with our first project

# %%
# A class to represent a Webpage
# If you're not familiar with Classes, check out the "Intermediate Python" notebook

# Some websites need you to use proper headers when fetching them:

# Why this is needed: Some websites block requests from "non-browser" clients (like scripts or bots). To avoid this, you pretend to be a real browser by setting a User-Agent header that matches a common browser (e.g., Chrome on Windows).

# This makes the request look like it’s coming from a regular user browsing with Chrome.
headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

class Website:

    def __init__(self, url):
        """
        Create this Website object from the given url using the BeautifulSoup library
        """
        self.url = url
        response = requests.get(url, headers=headers)
        soup = BeautifulSoup(response.content, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        # remove unwanted elements
        for irrelevant in soup.body(["script", "style", "img", "input"]):
            irrelevant.decompose()
        self.text = soup.body.get_text(separator="\n", strip=True)

# %%
# Let's try one out. Change the website and add print statements to follow along.

ed = Website("https://ered.gr/")
print(ed.title)
print(ed.text)
# Out:
# Αρχική | eRed
# ΕΙΣΟΔΟΣ/ΕΓΓΡΑΦΗ
# ΣΥΝΔΡΟΜΕΣ
# RED
# Red Forum
# RED Digital
# RED Ειδικές Εκδόσεις
# REDtv
# RED Meeting Point
# Nέα
# Deals
# Επενδύσεις
# Θεσμικοί Επενδυτές
# Εισηγμένες
# AEEAΠ
# Private Equity
# Αστικές Αναπλάσεις
# Αειφορία
# Καινοτομία
# Prop Tech
# Fin Tech
# Con Tech
# Υλικά
# Οικονομία
# Τουρισμός
# Υποδομές
# Ευ Ζειν
# Αρχιτεκτονική
# Design
# Projects
# Κατοικία
# Γραφεία
# Λιανεμπόριο
# Αποθήκες
# Ξενοδοχεία
# Μεικτής χρήσης
# Άλλο
# Θεσμικά
# Φορολογία
# Πολεοδομία
# Χωροταξία
# Νόμοι
# Αγορές
# Ελλάδα
# Αθήνα-Πειραιάς-Αττική
# Θεσσαλονίκη
# Κεντρική Ελλάδα
# Bόρεια Ελλάδα
# Νησιά Αιγαίου
# Πελοπόννησος
# Νησιά Ιονίου
# Κρήτη
# Ευρώπη
# Βαλκάνια
# Διεθνή
# Data
# Αναλύσεις
# Κλάδοι
# Kατοικία
# Γραφεία
# Λιανεμπόριο
# Αποθήκες
# Ξενοδοχεία
# Μεικτής χρήσης
# Άλλο
# DEALS
# Απόψεις
# Δείκτες
# ΧΑ
# EPRA
# Shiller
# Παρατηρητήριο Αγοράς
# Πώληση
# Ενοικίαση
# UrbanCodeRED
# ΕΤΑΙΡΕΙΕΣ
# Κατάλογοι
# Πρόσωπα
# Δελτία Τύπου
# AΓΓΕΛΙΕΣ
# Γραφεία
# Κατοικία
# Αποθήκες
# Λιανεμπόριο
# Ξενοδοχεία
# Οικόπεδο
# Άλλο
# Nέα
# Οικονομία
# Στην Βουλή ο νέος Νέος Αναπτυξιακός Νόμος
# 02.
# Tην REDS Hospitality ίδρυσε η Reds
# 03.
# Βγάζει εκτός βραχυχρόνιας μίσθωσης 66.000 αγγελίες η Ισπανία
# 04.
# Έσοδα από Μισθώματα στα €9,8 εκατ. για την Trade Estates το α' τρίμηνο 2025
# 05.
# Στην Δομική Κρήτης οι φοιτητικές εστίες του Παντείου Παν/μίου
# Share
# Copy Link
# Nέα
# Οικονομία
# Στοιχεία σοκ! Πρωτιά της Ελλάδας στην αύξηση των ηλικιωμένων σε ΕΕ
# Share
# Copy Link
# Nέα
# Τουρισμός
# |
# Data
# Αύξηση των αφίξεων και διανυκτερεύσεων σε καταλύματα το Μάρτιο 2025
# Share
# Copy Link
# Nέα
# Εισηγμένες
# Σε €0,45 δισ. τα κέρδη της ΔΕΗ για το α' τρίμηνο 2025
# Η διοίκηση προτείνει τη διανομή μερίσματος €0,4 / μετοχή.
# Share
# Copy Link
# Θεσμικά
# Χωροταξία
# Ρεκόρ παραγωγικότητας στο Ελληνικό Κτηματολόγιο
# Μέσα σε μια εβδομάδα ολοκληρώθηκαν 15.744 υποθέσεις.
# Share
# Copy Link
# Nέα
# Οικονομία
# |
# Αναλύσεις
# Η Ελλάδα στην κορυφή της αγοράς ναύλωσης πολυτελών σκαφών το 2024
# Newsletter
# Έγκυρη Καθημερινή
# Ενημέρωση
# για την Αγορά των Ακινήτων
# Subscribe
# Subscribe
# Newsletter
# ×
# Κλείσιμο
# ΠΑΡΑΤΗΡΗΤΗΡΙΟ
# Ενοικίαση
# Πώληση
# Καταστήματα
# Γραφεία
# Αποθήκες
# Ξενοδοχεία
# Είσοδος στο Παρατηρητήριο
# Deals
# Είσοδος στα Deals
# Δείκτες
# Είσοδος στους Δείκτες
# Περιοδικό
# Τρέχον Τεύχος
# Ειδικές Εκδόσεις
# 142
# 142
# Αρχείο
# Απόψεις
# 15.05.2025
# Κυριάκος Τσαταλπασίδης
# Ο αμερικανικός εξαιρετισμός στην δίνη των αγορών
# 24.04.2025
# Γιάννης Παπαχρήστου
# Μεγάλη η αβεβαιότητα των CEOs από τα εμπόδια στο διεθνές εμπόριο
# 22.04.2025
# Βασίλης Κορκίδης
# Οι τρεις λόγοι αύξησης του κύκλου εργασιών το Πάσχα
# ΕΠΙΛΟΓΕΣ
# Superb Detached Warehouse Facility
# EXCEPTIONAL STANDALONE OFFICE BUILDING FOR SALE & LEASE
# OFFICE SPACE OF 1,137 sqm - ATHENS NORTH, CHALANDRI
# STATE OF THE ART WAREHOUSE FOR LEASE IN KOROPI
# OFFICE BUILDING FOR LEASE IN METAMORFOSI
# Land plot in Moschato next to the Athens Festival
# Εξαιρετικό ακίνητο Logistic στη Μάνδρα
# FOR SALE HOTEL THROUGH E- AUCTION
# Share
# Copy Link
# Nέα
# Τουρισμός
# |
# Νησιά Αιγαίου
# H Ίος στους 10 κορυφαίους προορισμούς της Ευρώπης το 2025
# Το νησί σύμφωνα με στοιχεία του Ferryhopper βρέθηκε στη δεκάδα με βάση τις προτιμήσεις των τουριστών του εξωτερικού για το 2024.
# Share
# Copy Link
# Nέα
# Εισηγμένες
# Συμφωνία μεταξύ της Πειραιώς και της πλατφόρμας Skroutz
# Share
# Copy Link
# Αγορές
# Αθήνα-Πειραιάς-Αττική
# Tέλος Μαίου το 5ο Real Estate Forum
# Share
# Copy Link
# Nέα
# Υλικά
# |
# Γραφεία
# |
# Ευρώπη
# Πρωτοποριακό έργο "κατεδάφισης" από την Skanska στην Πράγα
# Τελευταία Νέα
# 21.05.2025
# Η EY φέρνει την AI στον πυρήνα των Ελεγκτικών Υπηρεσιών της
# 21.05.2025
# Διευρύνθηκε στα €3 δισ. το έλλειμμα τρεχουσών συναλλαγών τον Μάρτιο
# 21.05.2025
# Πρωτοποριακό έργο "κατεδάφισης" από την Skanska στην Πράγα
# 21.05.2025
# Είσοδος της Wynn Resorts σε Μέση Ανατολή και ΗΑΕ
# 21.05.2025
# Στοιχεία σοκ! Πρωτιά της Ελλάδας στην αύξηση των ηλικιωμένων σε ΕΕ
# 21.05.2025
# Στην Βουλή ο νέος Νέος Αναπτυξιακός Νόμος
# 21.05.2025
# Στην Δομική Κρήτης οι φοιτητικές εστίες του Παντείου Παν/μίου
# 21.05.2025
# Βγάζει εκτός βραχυχρόνιας μίσθωσης 66.000 αγγελίες η Ισπανία
# 21.05.2025
# Μεγαλύτερη η δύναμη του ελληνικού εμπορικού στόλου τον Μάρτιο
# 21.05.2025
# Αύξηση των αφίξεων και διανυκτερεύσεων σε καταλύματα το Μάρτιο 2025
# 21.05.2025
# Σε €0,45 δισ. τα κέρδη της ΔΕΗ για το α' τρίμηνο 2025
# 20.05.2025
# Tην REDS Hospitality ίδρυσε η Reds
# 20.05.2025
# Η Ελλάδα στην κορυφή της αγοράς ναύλωσης πολυτελών σκαφών το 2024
# 20.05.2025
# Συμφωνία μεταξύ της Πειραιώς και της πλατφόρμας Skroutz
# 20.05.2025
# Η Alpha Bank χρηματοδοτεί τέσσερα φωτοβολταϊκά πάρκα
# 20.05.2025
# Ντεμπούτο της Handwritten Collection με ξενοδοχείο στο Ηράκλειο Κρήτης
# 20.05.2025
# Ρεκόρ παραγωγικότητας στο Ελληνικό Κτηματολόγιο
# 20.05.2025
# Έσοδα από Μισθώματα στα €9,8 εκατ. για την Trade Estates το α' τρίμηνο 2025
# 20.05.2025
# Απέκτησε συνολικά 38.550.720 ίδιες μετοχές η Alpha Bank
# 20.05.2025
# H Ίος στους 10 κορυφαίους προορισμούς της Ευρώπης το 2025
# 20.05.2025
# Μέχρι τον Σεπτέμβρη η απόφαση του Ευρωπαϊκού Δικαστηρίου για το ΝΟΚ
# 20.05.2025
# Η Αθήνα στο επίκεντρο του Ευρωπαίων κατασκευαστών
# 20.05.2025
# Η ΕΤΑΔ νοίκιασε στον Δήμο Κω παραθαλάσσια έκταση στη Νέα Αλικαρνασσό
# 20.05.2025
# Η ATTICA GROUP πούλησε το πλοίο "ΚΡΗΤΗ Ι"
# 20.05.2025
# Ο όμιλος ΤΙΤΑΝ ολοκλήρωσε την πώληση του 75% της τουρκικής Adocim
# 20.05.2025
# Συμφωνία μαμούθ $11,5 δισ. της Blackstone
# 20.05.2025
# Οικοδομική άδεια για κατοικίες στο Μόναχο εξασφάλισε η Trei Real Estate
# 19.05.2025
# Tέλος Μαίου το 5ο Real Estate Forum
# 19.05.2025
# Σταθερά πάνω από τον μέσο όρο της ευρωζώνης και της ΕΕ, η ελληνική οικονομία
# 19.05.2025
# Η ΔΕΗ κατασκευάζει δύο Σταθμούς Αποθήκευσης Ενέργειας στη Δυτ. Μακεδονία
# 19.05.2025
# Ολλανδοί οι πιο δραστήριοι επενδυτές σε εξοχικά στην Ελλάδα
# 19.05.2025
# Οι Έλληνες CFOs επενδύουν στον ψηφιακό μετασχηματισμό
# 19.05.2025
# Τα πρώτα self-service καταστήματα στην Ελλάδα από την BOX NOW
# 19.05.2025
# Πρόγραμμα επαναγοράς μετοχών από την BNP Paribas
# 19.05.2025
# Ανοίγει το "Iulius Mall Suceava" μετά από επένδυση €40 εκατ.
# 19.05.2025
# Θερμό καλοκαίρι για τα airbnb. Διατηρεί τη θετική της δυναμική η Ελλάδα
# 19.05.2025
# Η Room00 με €400 εκατ. βάζει πλάνο για 200 ξενοδοχεία στη Νότια Ευρώπη
# 19.05.2025
# Τις προοπτικές της ελληνικής οικονομία αναβάθμισε ο οίκος Fitch
# 19.05.2025
# Μαγνήτης επενδύσεων ο Δήμος Βάρης - Βούλας - Βουλιαγμένης
# 19.05.2025
# Προς νέα μείωση επιτοκίων τον Ιούνιο η ΕΚΤ
# 19.05.2025
# Δάνεια €1,25 τρισ. έδωσε η Κεντρική Τράπεζα της Κίνας το α' τετράμηνο του 2025
# 19.05.2025
# Ξεμένει από νερό η Ελλάδα
# 19.05.2025
# Νέα εταιρεία "γεννιέται" στον κλάδο των ακινήτων
# 16.05.2025
# Τα €4 δισ. προσέγγισε το πρωτογενές πλεόνασμα το α' τετράμηνο
# 16.05.2025
# Μέσω του Ταμείου Ανάκαμψης ο εκσυγχρονισμός του ΕΔΥΤΕ
# 16.05.2025
# Ανοιχτό το ενδεχόμενο λήψης απόφασης για γεώτρηση το 2025 από την HelleniQ Energy
# 16.05.2025
# Νέος Γύρος Χρηματοδότησης €1.000.000 για την Protio
# 16.05.2025
# Δεύτερη η Ελλάδα παγκοσμίως με 657 βραβευμένες ακτές
# 16.05.2025
# Προς αλλαγή η φορολογία της μακροχρόνιας μίσθωσης
# 16.05.2025
# Οι εφτά προσφορές για την «Ακτή Βουλιαγμένης»
# 16.05.2025
# Πτώση στα κέρδη για την Helleniq Energy το α' τρίμηνο 2025
# 16.05.2025
# Ενώνουν δυνάμεις ONEX και Θριάσιο
# 16.05.2025
# Ποσοστό στα πολυκαταστήματα ERA απέκτησε η Fais
# 16.05.2025
# Οι δημόσιοι υπάλληλοι που θα εκπαιδευτούν σε cloud και ΑΙ τεχνολογίες
# 16.05.2025
# Προς $160 εκατ. πουλήθηκε πολυκατοικία στο Άμπου Ντάμπι
# 16.05.2025
# Νέο ρεκόρ κερδοφορίας το Α’ τρίμηνο του 2025 για την Attica Bank
# 15.05.2025
# Η SkyUp Airlines ξεκινά πτήσεις μεταξύ του Chisinau και της Αθήνας
# 15.05.2025
# Έσπασε το φράγμα των €3000 η μέση τιμή στα νεόδμητα (πίνακες)
# 15.05.2025
# Πάνω από 40% αυξήθηκαν οι τιμές των οικοπέδων σε βάθος δεκαετίας
# 15.05.2025
# Ξεκίνησαν οι αιτήσεις για το «Αλλάζω Σύστημα Θέρμανσης και Θερμοσίφωνα»
# 15.05.2025
# Το διεθνές βραβείο "Big SEE Architecture Award 2025" στο κτίριο κατοικιών «The Wave»
# 15.05.2025
# Νέα παράταση για το ΣΔΙΤ της Γενικής Γραμματείας Υποδομών
# 15.05.2025
# Κατατίθεται σήμερα το αναθεωρημένο σχέδιο για το Ταμείο Ανάκαμψης
# 15.05.2025
# Ψηφιακά η διαδικασία για την χορήγηση άδειας οδήγησης
# 15.05.2025
# Δέκα νέα έργα στο "μικροσκόπιο" της Noval Property
# 15.05.2025
# BriQ: Κατά 60% αυξήθηκαν τα καθαρά κέρδη α' τριμήνου
# 15.05.2025
# Οικονομική ασφάλεια, ποιότητα ζωής αναζητούν Gen Z και Millennials
# 15.05.2025
# Μείωση 2,5% στις τιμές εισαγωγών στη βιομηχανία τον Μάρτιο
# 14.05.2025
# Χαμηλώνει τον πήχη της ανάπτυξης η EBRD
# 14.05.2025
# Ανοδος το α' τρίμηνο 2025 για τα Venture Capital παγκοσμίως
# 14.05.2025
# Αύξηση κερδών κατά 19% για την Optima Bank το α' τρίμηνο του 2025
# 14.05.2025
# Στρατηγική συνεργασία ΓΕΚ ΤΕΡΝΑ και ΕΜΠ
# 14.05.2025
# Σε απόθεμα τρία δημοφιλή χρώματα στα αλουμίνια Europa
# 14.05.2025
# Ερευνα Randstad: Ποιες είναι οι πιο περιζήτητες θέσεις εργασίας
# 14.05.2025
# Διαθέσιμες στο gov.gr ακόμα τρεις υπηρεσίες
# 14.05.2025
# Πανεπιστημιακοί συνταξιούχοι χρηματοδοτούν Mega Data Center στην Βρετανία
# 14.05.2025
# Σε δημοσία διαβούλευση η επένδυση της Divine Property στην Σύρο
# 14.05.2025
# Εδωσε €30,2 δισ. το 2024 ο τουρισμός στην ελληνική οικονομία
# 14.05.2025
# Στη βουλή  η τροπολογία με τις αλλαγές στον ΝΟΚ
# 14.05.2025
# Το “Ardittos House” στο Μετς παρέδωσε η Noval
# 15.07.2024
# Dominique Moerenhout CEO, EPRA
# 15.07.2024
# Δημήτρης Ανδρίτσος CEO, Cerved Property Services
# 15.07.2024
# Hugh Kelly, Former International Chair, CRE
# 15.07.2024
# Samuel Duah, Head of Real Estate Economics, BNP Paribas Real Estate
# ECOΔΟΜΕΙΝ
# Share
# Copy Link
# Nέα
# Αρχιτεκτονική
# Το διεθνές βραβείο "Big SEE Architecture Award 2025" στο κτίριο κατοικιών «The Wave»
# Η ανάπτυξη της Potiropoulos+Partners βρίσκεται στο Γκολφ της Γλυφάδας.
# Ολοκληρώθηκε η ανακαίνιση των Village Cinemas στο The Mall Athens
# Εγκαίνια στο ελληνικό περίπτερο της 19ης Μπιενάλε Αρχιτεκτονικής στη Βενετία
# Η IKEA στην Oxford Street σχεδίασε προϊόντα για «πολύ μικρούς χώρους»
# Γίνε Συνδρομητής
# Εγγραφή στο Newsletter
# Γίνε Συνδρομητής
# Εγγραφή στο Newsletter
# Ποιοί Είμαστε
# Όροι Χρήσης
# Πολιτική Απορρήτου
# ©2021
# All rights reserved.

# %% [markdown]
# ## Types of prompts
#
# You may know this already - but if not, you will get very familiar with it!
#
# Models like GPT4o have been trained to receive instructions in a particular way.
#
# They expect to receive:
#
# **A system prompt** that tells them what task they are performing and what tone they should use
#
# **A user prompt** -- the conversation starter that they should reply to

# %%
# Define our system prompt - you can experiment with this later, changing the last sentence to 'Respond in markdown in Spanish."

system_prompt = "You are an assistant that analyzes the contents of a website \
and provides a short summary, ignoring text that might be navigation related. \
Respond in markdown."
# and in greek

# %%
# A function that writes a User Prompt that asks for summaries of websites:

def user_prompt_for(website):
    user_prompt = f"You are looking at a website titled {website.title}"
    user_prompt += "\nThe contents of this website is as follows; \
please provide a short summary of this website in markdown. \
If it includes news or announcements or recent ariticles, then summarize these too.\n\n"
    user_prompt += website.text
    return user_prompt

# %%
print(user_prompt_for(ed))
# Out:
# You are looking at a website titled Αρχική | eRed
# The contents of this website is as follows; please provide a short summary of this website in markdown. If it includes news or announcements or recent ariticles, then summarize these too.
#
# ΕΙΣΟΔΟΣ/ΕΓΓΡΑΦΗ
# ΣΥΝΔΡΟΜΕΣ
# RED
# Red Forum
# RED Digital
# RED Ειδικές Εκδόσεις
# REDtv
# RED Meeting Point
# Nέα
# Deals
# Επενδύσεις
# Θεσμικοί Επενδυτές
# Εισηγμένες
# AEEAΠ
# Private Equity
# Αστικές Αναπλάσεις
# Αειφορία
# Καινοτομία
# Prop Tech
# Fin Tech
# Con Tech
# Υλικά
# Οικονομία
# Τουρισμός
# Υποδομές
# Ευ Ζειν
# Αρχιτεκτονική
# Design
# Projects
# Κατοικία
# Γραφεία
# Λιανεμπόριο
# Αποθήκες
# Ξενοδοχεία
# Μεικτής χρήσης
# Άλλο
# Θεσμικά
# Φορολογία
# Πολεοδομία
# Χωροταξία
# Νόμοι
# Αγορές
# Ελλάδα
# Αθήνα-Πειραιάς-Αττική
# Θεσσαλονίκη
# Κεντρική Ελλάδα
# Bόρεια Ελλάδα
# Νησιά Αιγαίου
# Πελοπόννησος
# Νησιά Ιονίου
# Κρήτη
# Ευρώπη
# Βαλκάνια
# Διεθνή
# Data
# Αναλύσεις
# Κλάδοι
# Kατοικία
# Γραφεία
# Λιανεμπόριο
# Αποθήκες
# Ξενοδοχεία
# Μεικτής χρήσης
# Άλλο
# DEALS
# Απόψεις
# Δείκτες
# ΧΑ
# EPRA
# Shiller
# Παρατηρητήριο Αγοράς
# Πώληση
# Ενοικίαση
# UrbanCodeRED
# ΕΤΑΙΡΕΙΕΣ
# Κατάλογοι
# Πρόσωπα
# Δελτία Τύπου
# AΓΓΕΛΙΕΣ
# Γραφεία
# Κατοικία
# Αποθήκες
# Λιανεμπόριο
# Ξενοδοχεία
# Οικόπεδο
# Άλλο
# Nέα
# Οικονομία
# Στην Βουλή ο νέος Νέος Αναπτυξιακός Νόμος
# 02.
# Tην REDS Hospitality ίδρυσε η Reds
# 03.
# Βγάζει εκτός βραχυχρόνιας μίσθωσης 66.000 αγγελίες η Ισπανία
# 04.
# Έσοδα από Μισθώματα στα €9,8 εκατ. για την Trade Estates το α' τρίμηνο 2025
# 05.
# Στην Δομική Κρήτης οι φοιτητικές εστίες του Παντείου Παν/μίου
# Share
# Copy Link
# Nέα
# Οικονομία
# Στοιχεία σοκ! Πρωτιά της Ελλάδας στην αύξηση των ηλικιωμένων σε ΕΕ
# Share
# Copy Link
# Nέα
# Τουρισμός
# |
# Data
# Αύξηση των αφίξεων και διανυκτερεύσεων σε καταλύματα το Μάρτιο 2025
# Share
# Copy Link
# Nέα
# Εισηγμένες
# Σε €0,45 δισ. τα κέρδη της ΔΕΗ για το α' τρίμηνο 2025
# Η διοίκηση προτείνει τη διανομή μερίσματος €0,4 / μετοχή.
# Share
# Copy Link
# Θεσμικά
# Χωροταξία
# Ρεκόρ παραγωγικότητας στο Ελληνικό Κτηματολόγιο
# Μέσα σε μια εβδομάδα ολοκληρώθηκαν 15.744 υποθέσεις.
# Share
# Copy Link
# Nέα
# Οικονομία
# |
# Αναλύσεις
# Η Ελλάδα στην κορυφή της αγοράς ναύλωσης πολυτελών σκαφών το 2024
# Newsletter
# Έγκυρη Καθημερινή
# Ενημέρωση
# για την Αγορά των Ακινήτων
# Subscribe
# Subscribe
# Newsletter
# ×
# Κλείσιμο
# ΠΑΡΑΤΗΡΗΤΗΡΙΟ
# Ενοικίαση
# Πώληση
# Καταστήματα
# Γραφεία
# Αποθήκες
# Ξενοδοχεία
# Είσοδος στο Παρατηρητήριο
# Deals
# Είσοδος στα Deals
# Δείκτες
# Είσοδος στους Δείκτες
# Περιοδικό
# Τρέχον Τεύχος
# Ειδικές Εκδόσεις
# 142
# 142
# Αρχείο
# Απόψεις
# 15.05.2025
# Κυριάκος Τσαταλπασίδης
# Ο αμερικανικός εξαιρετισμός στην δίνη των αγορών
# 24.04.2025
# Γιάννης Παπαχρήστου
# Μεγάλη η αβεβαιότητα των CEOs από τα εμπόδια στο διεθνές εμπόριο
# 22.04.2025
# Βασίλης Κορκίδης
# Οι τρεις λόγοι αύξησης του κύκλου εργασιών το Πάσχα
# ΕΠΙΛΟΓΕΣ
# Superb Detached Warehouse Facility
# EXCEPTIONAL STANDALONE OFFICE BUILDING FOR SALE & LEASE
# OFFICE SPACE OF 1,137 sqm - ATHENS NORTH, CHALANDRI
# STATE OF THE ART WAREHOUSE FOR LEASE IN KOROPI
# OFFICE BUILDING FOR LEASE IN METAMORFOSI
# Land plot in Moschato next to the Athens Festival
# Εξαιρετικό ακίνητο Logistic στη Μάνδρα
# FOR SALE HOTEL THROUGH E- AUCTION
# Share
# Copy Link
# Nέα
# Τουρισμός
# |
# Νησιά Αιγαίου
# H Ίος στους 10 κορυφαίους προορισμούς της Ευρώπης το 2025
# Το νησί σύμφωνα με στοιχεία του Ferryhopper βρέθηκε στη δεκάδα με βάση τις προτιμήσεις των τουριστών του εξωτερικού για το 2024.
# Share
# Copy Link
# Nέα
# Εισηγμένες
# Συμφωνία μεταξύ της Πειραιώς και της πλατφόρμας Skroutz
# Share
# Copy Link
# Αγορές
# Αθήνα-Πειραιάς-Αττική
# Tέλος Μαίου το 5ο Real Estate Forum
# Share
# Copy Link
# Nέα
# Υλικά
# |
# Γραφεία
# |
# Ευρώπη
# Πρωτοποριακό έργο "κατεδάφισης" από την Skanska στην Πράγα
# Τελευταία Νέα
# 21.05.2025
# Η EY φέρνει την AI στον πυρήνα των Ελεγκτικών Υπηρεσιών της
# 21.05.2025
# Διευρύνθηκε στα €3 δισ. το έλλειμμα τρεχουσών συναλλαγών τον Μάρτιο
# 21.05.2025
# Πρωτοποριακό έργο "κατεδάφισης" από την Skanska στην Πράγα
# 21.05.2025
# Είσοδος της Wynn Resorts σε Μέση Ανατολή και ΗΑΕ
# 21.05.2025
# Στοιχεία σοκ! Πρωτιά της Ελλάδας στην αύξηση των ηλικιωμένων σε ΕΕ
# 21.05.2025
# Στην Βουλή ο νέος Νέος Αναπτυξιακός Νόμος
# 21.05.2025
# Στην Δομική Κρήτης οι φοιτητικές εστίες του Παντείου Παν/μίου
# 21.05.2025
# Βγάζει εκτός βραχυχρόνιας μίσθωσης 66.000 αγγελίες η Ισπανία
# 21.05.2025
# Μεγαλύτερη η δύναμη του ελληνικού εμπορικού στόλου τον Μάρτιο
# 21.05.2025
# Αύξηση των αφίξεων και διανυκτερεύσεων σε καταλύματα το Μάρτιο 2025
# 21.05.2025
# Σε €0,45 δισ. τα κέρδη της ΔΕΗ για το α' τρίμηνο 2025
# 20.05.2025
# Tην REDS Hospitality ίδρυσε η Reds
# 20.05.2025
# Η Ελλάδα στην κορυφή της αγοράς ναύλωσης πολυτελών σκαφών το 2024
# 20.05.2025
# Συμφωνία μεταξύ της Πειραιώς και της πλατφόρμας Skroutz
# 20.05.2025
# Η Alpha Bank χρηματοδοτεί τέσσερα φωτοβολταϊκά πάρκα
# 20.05.2025
# Ντεμπούτο της Handwritten Collection με ξενοδοχείο στο Ηράκλειο Κρήτης
# 20.05.2025
# Ρεκόρ παραγωγικότητας στο Ελληνικό Κτηματολόγιο
# 20.05.2025
# Έσοδα από Μισθώματα στα €9,8 εκατ. για την Trade Estates το α' τρίμηνο 2025
# 20.05.2025
# Απέκτησε συνολικά 38.550.720 ίδιες μετοχές η Alpha Bank
# 20.05.2025
# H Ίος στους 10 κορυφαίους προορισμούς της Ευρώπης το 2025
# 20.05.2025
# Μέχρι τον Σεπτέμβρη η απόφαση του Ευρωπαϊκού Δικαστηρίου για το ΝΟΚ
# 20.05.2025
# Η Αθήνα στο επίκεντρο του Ευρωπαίων κατασκευαστών
# 20.05.2025
# Η ΕΤΑΔ νοίκιασε στον Δήμο Κω παραθαλάσσια έκταση στη Νέα Αλικαρνασσό
# 20.05.2025
# Η ATTICA GROUP πούλησε το πλοίο "ΚΡΗΤΗ Ι"
# 20.05.2025
# Ο όμιλος ΤΙΤΑΝ ολοκλήρωσε την πώληση του 75% της τουρκικής Adocim
# 20.05.2025
# Συμφωνία μαμούθ $11,5 δισ. της Blackstone
# 20.05.2025
# Οικοδομική άδεια για κατοικίες στο Μόναχο εξασφάλισε η Trei Real Estate
# 19.05.2025
# Tέλος Μαίου το 5ο Real Estate Forum
# 19.05.2025
# Σταθερά πάνω από τον μέσο όρο της ευρωζώνης και της ΕΕ, η ελληνική οικονομία
# 19.05.2025
# Η ΔΕΗ κατασκευάζει δύο Σταθμούς Αποθήκευσης Ενέργειας στη Δυτ. Μακεδονία
# 19.05.2025
# Ολλανδοί οι πιο δραστήριοι επενδυτές σε εξοχικά στην Ελλάδα
# 19.05.2025
# Οι Έλληνες CFOs επενδύουν στον ψηφιακό μετασχηματισμό
# 19.05.2025
# Τα πρώτα self-service καταστήματα στην Ελλάδα από την BOX NOW
# 19.05.2025
# Πρόγραμμα επαναγοράς μετοχών από την BNP Paribas
# 19.05.2025
# Ανοίγει το "Iulius Mall Suceava" μετά από επένδυση €40 εκατ.
# 19.05.2025
# Θερμό καλοκαίρι για τα airbnb. Διατηρεί τη θετική της δυναμική η Ελλάδα
# 19.05.2025
# Η Room00 με €400 εκατ. βάζει πλάνο για 200 ξενοδοχεία στη Νότια Ευρώπη
# 19.05.2025
# Τις προοπτικές της ελληνικής οικονομία αναβάθμισε ο οίκος Fitch
# 19.05.2025
# Μαγνήτης επενδύσεων ο Δήμος Βάρης - Βούλας - Βουλιαγμένης
# 19.05.2025
# Προς νέα μείωση επιτοκίων τον Ιούνιο η ΕΚΤ
# 19.05.2025
# Δάνεια €1,25 τρισ. έδωσε η Κεντρική Τράπεζα της Κίνας το α' τετράμηνο του 2025
# 19.05.2025
# Ξεμένει από νερό η Ελλάδα
# 19.05.2025
# Νέα εταιρεία "γεννιέται" στον κλάδο των ακινήτων
# 16.05.2025
# Τα €4 δισ. προσέγγισε το πρωτογενές πλεόνασμα το α' τετράμηνο
# 16.05.2025
# Μέσω του Ταμείου Ανάκαμψης ο εκσυγχρονισμός του ΕΔΥΤΕ
# 16.05.2025
# Ανοιχτό το ενδεχόμενο λήψης απόφασης για γεώτρηση το 2025 από την HelleniQ Energy
# 16.05.2025
# Νέος Γύρος Χρηματοδότησης €1.000.000 για την Protio
# 16.05.2025
# Δεύτερη η Ελλάδα παγκοσμίως με 657 βραβευμένες ακτές
# 16.05.2025
# Προς αλλαγή η φορολογία της μακροχρόνιας μίσθωσης
# 16.05.2025
# Οι εφτά προσφορές για την «Ακτή Βουλιαγμένης»
# 16.05.2025
# Πτώση στα κέρδη για την Helleniq Energy το α' τρίμηνο 2025
# 16.05.2025
# Ενώνουν δυνάμεις ONEX και Θριάσιο
# 16.05.2025
# Ποσοστό στα πολυκαταστήματα ERA απέκτησε η Fais
# 16.05.2025
# Οι δημόσιοι υπάλληλοι που θα εκπαιδευτούν σε cloud και ΑΙ τεχνολογίες
# 16.05.2025
# Προς $160 εκατ. πουλήθηκε πολυκατοικία στο Άμπου Ντάμπι
# 16.05.2025
# Νέο ρεκόρ κερδοφορίας το Α’ τρίμηνο του 2025 για την Attica Bank
# 15.05.2025
# Η SkyUp Airlines ξεκινά πτήσεις μεταξύ του Chisinau και της Αθήνας
# 15.05.2025
# Έσπασε το φράγμα των €3000 η μέση τιμή στα νεόδμητα (πίνακες)
# 15.05.2025
# Πάνω από 40% αυξήθηκαν οι τιμές των οικοπέδων σε βάθος δεκαετίας
# 15.05.2025
# Ξεκίνησαν οι αιτήσεις για το «Αλλάζω Σύστημα Θέρμανσης και Θερμοσίφωνα»
# 15.05.2025
# Το διεθνές βραβείο "Big SEE Architecture Award 2025" στο κτίριο κατοικιών «The Wave»
# 15.05.2025
# Νέα παράταση για το ΣΔΙΤ της Γενικής Γραμματείας Υποδομών
# 15.05.2025
# Κατατίθεται σήμερα το αναθεωρημένο σχέδιο για το Ταμείο Ανάκαμψης
# 15.05.2025
# Ψηφιακά η διαδικασία για την χορήγηση άδειας οδήγησης
# 15.05.2025
# Δέκα νέα έργα στο "μικροσκόπιο" της Noval Property
# 15.05.2025
# BriQ: Κατά 60% αυξήθηκαν τα καθαρά κέρδη α' τριμήνου
# 15.05.2025
# Οικονομική ασφάλεια, ποιότητα ζωής αναζητούν Gen Z και Millennials
# 15.05.2025
# Μείωση 2,5% στις τιμές εισαγωγών στη βιομηχανία τον Μάρτιο
# 14.05.2025
# Χαμηλώνει τον πήχη της ανάπτυξης η EBRD
# 14.05.2025
# Ανοδος το α' τρίμηνο 2025 για τα Venture Capital παγκοσμίως
# 14.05.2025
# Αύξηση κερδών κατά 19% για την Optima Bank το α' τρίμηνο του 2025
# 14.05.2025
# Στρατηγική συνεργασία ΓΕΚ ΤΕΡΝΑ και ΕΜΠ
# 14.05.2025
# Σε απόθεμα τρία δημοφιλή χρώματα στα αλουμίνια Europa
# 14.05.2025
# Ερευνα Randstad: Ποιες είναι οι πιο περιζήτητες θέσεις εργασίας
# 14.05.2025
# Διαθέσιμες στο gov.gr ακόμα τρεις υπηρεσίες
# 14.05.2025
# Πανεπιστημιακοί συνταξιούχοι χρηματοδοτούν Mega Data Center στην Βρετανία
# 14.05.2025
# Σε δημοσία διαβούλευση η επένδυση της Divine Property στην Σύρο
# 14.05.2025
# Εδωσε €30,2 δισ. το 2024 ο τουρισμός στην ελληνική οικονομία
# 14.05.2025
# Στη βουλή  η τροπολογία με τις αλλαγές στον ΝΟΚ
# 14.05.2025
# Το “Ardittos House” στο Μετς παρέδωσε η Noval
# 15.07.2024
# Dominique Moerenhout CEO, EPRA
# 15.07.2024
# Δημήτρης Ανδρίτσος CEO, Cerved Property Services
# 15.07.2024
# Hugh Kelly, Former International Chair, CRE
# 15.07.2024
# Samuel Duah, Head of Real Estate Economics, BNP Paribas Real Estate
# ECOΔΟΜΕΙΝ
# Share
# Copy Link
# Nέα
# Αρχιτεκτονική
# Το διεθνές βραβείο "Big SEE Architecture Award 2025" στο κτίριο κατοικιών «The Wave»
# Η ανάπτυξη της Potiropoulos+Partners βρίσκεται στο Γκολφ της Γλυφάδας.
# Ολοκληρώθηκε η ανακαίνιση των Village Cinemas στο The Mall Athens
# Εγκαίνια στο ελληνικό περίπτερο της 19ης Μπιενάλε Αρχιτεκτονικής στη Βενετία
# Η IKEA στην Oxford Street σχεδίασε προϊόντα για «πολύ μικρούς χώρους»
# Γίνε Συνδρομητής
# Εγγραφή στο Newsletter
# Γίνε Συνδρομητής
# Εγγραφή στο Newsletter
# Ποιοί Είμαστε
# Όροι Χρήσης
# Πολιτική Απορρήτου
# ©2021
# All rights reserved.

# %% [markdown]
# ## Messages
#
# The API from OpenAI expects to receive messages in a particular structure.
# Many of the other APIs share this structure:
#
# ```python
# [
#     {"role": "system", "content": "system message goes here"},
#     {"role": "user", "content": "user message goes here"}
# ]
# ```
# To give you a preview, the next 2 cells make a rather simple call - we won't stretch the mighty GPT (yet!)

# %% [markdown]
# ## And now let's build useful messages for GPT-4o-mini, using a function

# %%
# See how this function creates exactly the format above

def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_for(website)}
    ]

# %%
# Try this out, and then try for a few more websites

messages_for(ed)
# Out:
# [{'role': 'system',
#   'content': 'You are an assistant that analyzes the contents of a website and provides a short summary, ignoring text that might be navigation related. Respond in markdown.'},
#  {'role': 'user',
#   'content': 'You are looking at a website titled Αρχική | eRed\nThe contents of this website is as follows; please provide a short summary of this website in markdown. If it includes news or announcements or recent ariticles, then summarize these too.\n\nΕΙΣΟΔΟΣ/ΕΓΓΡΑΦΗ\nΣΥΝΔΡΟΜΕΣ\nRED\nRed Forum\nRED Digital\nRED Ειδικές Εκδόσεις\nREDtv\nRED Meeting Point\nNέα\nDeals\nΕπενδύσεις\nΘεσμικοί Επενδυτές\nΕισηγμένες\nAEEAΠ\nPrivate Equity\nΑστικές Αναπλάσεις\nΑειφορία\nΚαινοτομία\nProp Tech\nFin Tech\nCon Tech\nΥλικά\nΟικονομία\nΤουρισμός\nΥποδομές\nΕυ Ζειν\nΑρχιτεκτονική\nDesign\nProjects\nΚατοικία\nΓραφεία\nΛιανεμπόριο\nΑποθήκες\nΞενοδοχεία\nΜεικτής χρήσης\nΆλλο\nΘεσμικά\nΦορολογία\nΠολεοδομία\nΧωροταξία\nΝόμοι\nΑγορές\nΕλλάδα\nΑθήνα-Πειραιάς-Αττική\nΘεσσαλονίκη\nΚεντρική Ελλάδα\nBόρεια Ελλάδα\nΝησιά Αιγαίου\nΠελοπόννησος\nΝησιά Ιονίου\nΚρήτη\nΕυρώπη\nΒαλκάνια\nΔιεθνή\nData\nΑναλύσεις\nΚλάδοι\nKατοικία\nΓραφεία\nΛιανεμπόριο\nΑποθήκες\nΞενοδοχεία\nΜεικτής χρήσης\nΆλλο\nDEALS\nΑπόψεις\nΔείκτες\nΧΑ\nEPRA\nShiller\nΠαρατηρητήριο Αγοράς\nΠώληση\nΕνοικίαση\nUrbanCodeRED\nΕΤΑΙΡΕΙΕΣ\nΚατάλογοι\nΠρόσωπα\nΔελτία Τύπου\nAΓΓΕΛΙΕΣ\nΓραφεία\nΚατοικία\nΑποθήκες\nΛιανεμπόριο\nΞενοδοχεία\nΟικόπεδο\nΆλλο\nNέα\nΟικονομία\nΣτην Βουλή ο νέος Νέος Αναπτυξιακός Νόμος\n02.\nTην REDS Hospitality ίδρυσε η Reds\n03.\nΒγάζει εκτός βραχυχρόνιας μίσθωσης 66.000 αγγελίες η Ισπανία\n04.\nΈσοδα από Μισθώματα στα €9,8 εκατ. για την Trade Estates το α\' τρίμηνο 2025\n05.\nΣτην Δομική Κρήτης οι φοιτητικές εστίες του Παντείου Παν/μίου\nShare\nCopy Link\nNέα\nΟικονομία\nΣτοιχεία σοκ! Πρωτιά της Ελλάδας στην αύξηση των ηλικιωμένων σε ΕΕ\nShare\nCopy Link\nNέα\nΤουρισμός\n|\nData\nΑύξηση των αφίξεων και διανυκτερεύσεων σε καταλύματα το Μάρτιο 2025\nShare\nCopy Link\nNέα\nΕισηγμένες\nΣε €0,45 δισ. τα κέρδη της ΔΕΗ για το α\' τρίμηνο 2025\nΗ διοίκηση προτείνει τη διανομή μερίσματος €0,4 / μετοχή.\nShare\nCopy Link\nΘεσμικά\nΧωροταξία\nΡεκόρ παραγωγικότητας στο Ελληνικό Κτηματολόγιο\nΜέσα σε μια εβδομάδα ολοκληρώθηκαν 15.744 υποθέσεις.\nShare\nCopy Link\nNέα\nΟικονομία\n|\nΑναλύσεις\nΗ Ελλάδα στην κορυφή της αγοράς ναύλωσης πολυτελών σκαφών το 2024\nNewsletter\nΈγκυρη Καθημερινή\nΕνημέρωση\nγια την Αγορά των Ακινήτων\nSubscribe\nSubscribe\nNewsletter\n×\nΚλείσιμο\nΠΑΡΑΤΗΡΗΤΗΡΙΟ\nΕνοικίαση\nΠώληση\nΚαταστήματα\nΓραφεία\nΑποθήκες\nΞενοδοχεία\nΕίσοδος στο Παρατηρητήριο\nDeals\nΕίσοδος στα Deals\nΔείκτες\nΕίσοδος στους Δείκτες\nΠεριοδικό\nΤρέχον Τεύχος\nΕιδικές Εκδόσεις\n142\n142\nΑρχείο\nΑπόψεις\n15.05.2025\nΚυριάκος Τσαταλπασίδης\nΟ αμερικανικός εξαιρετισμός στην δίνη των αγορών\n24.04.2025\nΓιάννης Παπαχρήστου\nΜεγάλη η αβεβαιότητα των CEOs από τα εμπόδια στο διεθνές εμπόριο\n22.04.2025\nΒασίλης Κορκίδης\nΟι τρεις λόγοι αύξησης του κύκλου εργασιών το Πάσχα\nΕΠΙΛΟΓΕΣ\nSuperb Detached Warehouse Facility\nEXCEPTIONAL STANDALONE OFFICE BUILDING FOR SALE & LEASE\nOFFICE SPACE OF 1,137 sqm - ATHENS NORTH, CHALANDRI\nSTATE OF THE ART WAREHOUSE FOR LEASE IN KOROPI\nOFFICE BUILDING FOR LEASE IN METAMORFOSI\nLand plot in Moschato next to the Athens Festival\nΕξαιρετικό ακίνητο Logistic στη Μάνδρα\nFOR SALE HOTEL THROUGH E- AUCTION\nShare\nCopy Link\nNέα\nΤουρισμός\n|\nΝησιά Αιγαίου\nH Ίος στους 10 κορυφαίους προορισμούς της Ευρώπης το 2025\nΤο νησί σύμφωνα με στοιχεία του Ferryhopper βρέθηκε στη δεκάδα με βάση τις προτιμήσεις των τουριστών του εξωτερικού για το 2024.\nShare\nCopy Link\nNέα\nΕισηγμένες\nΣυμφωνία μεταξύ της Πειραιώς και της πλατφόρμας Skroutz\nShare\nCopy Link\nΑγορές\nΑθήνα-Πειραιάς-Αττική\nTέλος Μαίου το 5ο Real Estate Forum\nShare\nCopy Link\nNέα\nΥλικά\n|\nΓραφεία\n|\nΕυρώπη\nΠρωτοποριακό έργο "κατεδάφισης" από την Skanska στην Πράγα\nΤελευταία Νέα\n21.05.2025\nΗ EY φέρνει την AI στον πυρήνα των Ελεγκτικών Υπηρεσιών της\n21.05.2025\nΔιευρύνθηκε στα €3 δισ. το έλλειμμα τρεχουσών συναλλαγών τον Μάρτιο\n21.05.2025\nΠρωτοποριακό έργο "κατεδάφισης" από την Skanska στην Πράγα\n21.05.2025\nΕίσοδος της Wynn Resorts σε Μέση Ανατολή και ΗΑΕ\n21.05.2025\nΣτοιχεία σοκ! Πρωτι ...

# %% [markdown]
# ## Time to bring it together - the API for OpenAI is very simple!

# %%
# And now: call the OpenAI API. You will get very familiar with this!

def summarize(url):
    website = Website(url)
    response = openai.chat.completions.create(
        model = "gpt-4o-mini",
        messages = messages_for(website)
    )
    return response.choices[0].message.content

# %%
# A function to display this nicely in the Jupyter output, using markdown

def display_summary(url):
    summary = summarize(url)
    display(Markdown(summary))

# %% [markdown]
# # Let's try more websites
#
# Note that this will only work on websites that can be scraped using this simplistic approach.
#
# Websites that are rendered with Javascript, like React apps, won't show up. See the community-contributions folder for a Selenium implementation that gets around this. You'll need to read up on installing Selenium (ask ChatGPT!)
#
# Also Websites protected with CloudFront (and similar) may give 403 errors - many thanks Andy J for pointing this out.
#
# But many websites will work just fine!

# %%
display_summary("https://cnn.com")
# Out:
# # Summary of CNN Website
#
# CNN provides comprehensive coverage of breaking news from around the world. The site includes sections dedicated to various topics such as US and world news, politics, business, health, entertainment, sports, science, and climate.
#
# ## Recent Articles and Highlights
# - **Ukraine-Russia War**: The website reports on significant events such as Putin's first visit to the Kursk region since Ukrainian forces were reportedly repelled.
# - **Israel-Hamas Conflict**: Updates indicate that the US is mediating ceasefire negotiations, with escalating pressures on Israel amid a looming humanitarian crisis in Gaza.
# - **Global Incidents**: Articles cover a variety of topics including the arrest of an Indian YouTuber for allegedly spying during travels, chaos in Gaza during food drives, and significant local events like the assassination of a mayor's aide in Mexico City.
# - **Science and Environment**: Reports highlight dangerous levels of heavy metals found in store-bought rice and environmental concerns related to global warming's impact on ice sheets.
#
# Overall, CNN emphasizes the diverse nature of both national and international affairs, aiming to keep readers informed about critical issues as they unfold.

# %%
display_summary("https://ered.gr")
# Out:
# # Summary of eRed Website
#
# The **eRed** website serves as a comprehensive platform focusing on various sectors related to the real estate market and investment opportunities in Greece and beyond. Key sections include information on:
#
# - **Real Estate**: This includes insights into different types of properties such as residential, commercial, mixed-use, and logistics.
# - **Economics**: Covering economic analyses, trends, and implications for various sectors including tourism, construction, and investments.
# - **Legislation**: Updates on legal frameworks affecting real estate and urban planning.
# - **Data & Analysis**: Providing data-driven insights and analyses over several industry sectors.
# - **News & Announcements**: Regular updates with critical developments in the economy, real estate market, and significant corporate announcements.
#
# ## Recent News Highlights
# Here are a few key announcements from the "Nέα" section:
#
# 1. **New Development Law**: A new development law has been introduced to the Greek Parliament.
# 2. **REDS Hospitality**: The establishment of REDS Hospitality by Reds.
# 3. **Rental Market Adjustments in Spain**: Spain has removed 66,000 short-term rental listings from the market.
# 4. **DEI Profits**: DEI reported profits of €0.45 billion in Q1 2025, with a proposed dividend of €0.40 per share.
# 5. **Increase in Tourist Arrivals**: An increase in arrivals and overnight stays in accommodations was noted for March 2025.
# 6. **Record Productivity**: The Greek Cadastre reported record productivity with over 15,000 cases resolved within a week.
#
# Overall, eRed is positioned as an essential resource for real estate professionals, investors, and those interested in market trends within Greece.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business applications</h2>
#             <span style="color:#181;">In this exercise, you experienced calling the Cloud API of a Frontier Model (a leading model at the frontier of AI) for the first time. We will be using APIs like OpenAI at many stages in the course, in addition to building our own LLMs.
#
# More specifically, we've applied this to Summarization - a classic Gen AI use case to make a summary. This can be applied to any business vertical - summarizing the news, summarizing financial performance, summarizing a resume in a cover letter - the applications are limitless. Consider how you could apply Summarization in your business, and try prototyping a solution.</span>
#         </td>
#     </tr>
# </table>
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you continue - now try yourself</h2>
#             <span style="color:#900;">Use the cell below to make your own simple commercial example. Stick with the summarization use case for now. Here's an idea: write something that will take the contents of an email, and will suggest an appropriate short subject line for the email. That's the kind of feature that might be built into a commercial email tool.</span>
#         </td>
#     </tr>
# </table>

# %%
# Step 1: Create your prompts

system_prompt = "something here"
user_prompt = """
    Lots of text
    Can be pasted here
"""

# Step 2: Make the messages list

messages = [] # fill this in

# Step 3: Call OpenAI

response =

# Step 4: print the result

print(

# %% [markdown]
# ## An extra exercise for those who enjoy web scraping
#
# You may notice that if you try `display_summary("https://openai.com")` - it doesn't work! That's because OpenAI has a fancy website that uses Javascript. There are many ways around this that some of you might be familiar with. For example, Selenium is a hugely popular framework that runs a browser behind the scenes, renders the page, and allows you to query it. If you have experience with Selenium, Playwright or similar, then feel free to improve the Website class to use them. In the community-contributions folder, you'll find an example Selenium solution from a student (thank you!)

# %% [markdown]
# # Sharing your code
#
# I'd love it if you share your code afterwards so I can share it with others! You'll notice that some students have already made changes (including a Selenium implementation) which you will find in the community-contributions folder. If you'd like add your changes to that folder, submit a Pull Request with your new versions in that folder and I'll merge your changes.
#
# If you're not an expert with git (and I am not!) then GPT has given some nice instructions on how to submit a Pull Request. It's a bit of an involved process, but once you've done it once it's pretty clear. As a pro-tip: it's best if you clear the outputs of your Jupyter notebooks (Edit >> Clean outputs of all cells, and then Save) for clean notebooks.
#
# Here are good instructions courtesy of an AI friend:
# https://chatgpt.com/share/677a9cb5-c64c-8012-99e0-e06e88afd293
